# %% [markdown]
# ## Plots of the results

# %%
from plotting.plot_solutions import plot_runtime, plot_2d_solution, plot_solution_validation, plot_solutions_compare

# %% [markdown]
# #### How the input values are set

# %%
# The problem type: ModifiedSod, Test2, Test3, Test5
problem_type = "ModifiedSod"
# Tthe solver: ExactRiemann [0], LaxFriedrichs [1], Roe [2], Osher [3]
solver = 0
# The number of cells for spatial discretization
n_cells = 100
# The time of output for the simulation 
output_time = 0.05

# %% [markdown]
# #### Exact Riemann solution compared to validation data

# %%
problem_type = "ModifiedSod"
solver = 3
n_cells = 100
output_time = 0.2

plot_solution_validation(problem_type, solver, n_cells, output_time)

# %%
problem_type = "ModifiedSod"
solver = 0
n_cells = 100
output_time = 0.2

plot_solution_validation(problem_type, solver, n_cells, output_time)

# %% [markdown]
# #### Compare the results from different solvers

# %% [markdown]
# ##### ModifiedSod

# %%
problem_type = "ModifiedSod"
solver_list = [0, 1, 2, 3]
n_cells = 100
output_time = 0.2
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %%
problem_type = "ModifiedSod"
solver_list = [0, 1, 2, 3]
n_cells = 500
output_time = 0.2
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %% [markdown]
# ##### Test2

# %%
problem_type = "Test2"
solver_list = [0, 1, 3]
n_cells = 100
output_time = 0.15
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %%
problem_type = "Test2"
solver_list = [0, 1, 2, 3]
n_cells = 500
output_time = 0.15
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %% [markdown]
# ##### Test3

# %%
problem_type = "Test3"
solver_list = [0, 1, 2, 3]
n_cells = 100
output_time = 0.012
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %%
problem_type = "Test3"
solver_list = [0, 1, 2, 3]
n_cells = 500
output_time = 0.012
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %% [markdown]
# ##### Test5

# %%
problem_type = "Test5"
solver_list = [0, 1, 2]
n_cells = 100
output_time = 0.012
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %%
problem_type = "Test5"
solver_list = [0, 1, 2]
n_cells = 500
output_time = 0.012
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %%
problem_type = "Test5"
solver_list = [0, 3]
n_cells = 500
output_time = 0.012
plot_solutions_compare(problem_type, solver_list, n_cells, output_time)

# %% [markdown]
# #### Compare the runtime for all solvers at same output time and increasing cell number

# %%
problem_type = "ModifiedSod"
solver_list = [0, 1, 2, 3]
output_time = 0.2
n_cells_list = [100, 200, 300, 400, 500, 700, 1000, 2000]

plot_runtime(problem_type, solver_list, output_time, n_cells_list)

# %% [markdown]
# #### Example of the x/t graph

# %%
problem_type = "ModifiedSod"
solver = 0
n_cells = 100
output_time_start = 0.05
output_time_end = 0.4
output_time_step = 0.05

plot_2d_solution(problem_type, solver, n_cells, output_time_start, output_time_step, output_time_end)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 8
#       5 output_time_end = 0.4
#       6 output_time_step = 0.05
# ----> 8 plot_2d_solution(problem_type, solver, n_cells, output_time_start, output_time_step, output_time_end)
#
# File /mnt/c/Users/beatr/Documents/cse/Fluid/ctfd/project/numerica/plotting/plot_solutions.py:151, in plot_2d_solution(problem_type, solver, n_cells, output_time_start, output_time_step, output_time_end)
#     148 for i, output_time in enumerate(output_time_array):
#     149     # Read the .out file
#     150     file_path = os.path.join(script_dir, '..', f"output/{problem_type}", f'solver{solver}_t{output_time:.3f}_n{n_cells}.out')
# --> 151     data = pd.read_csv(file_path, sep='\s+', header=None)
#     153     # Read data into columns
#     154     columns = np.zeros((data.shape[1],data.shape[0]))
#
# ...
